# %% [markdown]
# # User Story 3 : Entraînement des modèles de clustering avec K-Means

# %% [markdown]
# ## Détermination de la valeur optimale de k avec les méthodes du coude et du silhouette

# %%
from utils1 import *
from sklearn.cluster import KMeans
content = load_data()

sse = []
k = range(1,10)
for i in k:
    kmeans = KMeans(n_clusters=i,random_state=42)
    kmeans.fit(content)
    sse.append(kmeans.inertia_)
mpt.plot(k,sse,'bx-')
mpt.xlabel('Nombres de clusters K ')
mpt.ylabel('SSE (inertia)')
mpt.title('Méthode de coude')
mpt.show()

# %% [markdown]
# ## Évaluation de la qualité du regroupement à l’aide du score de silhouette

# %%
from sklearn.metrics import silhouette_score
k = range(2,10)
for i in k:
    kmeans = KMeans(n_clusters=i,random_state=42)
    labels = kmeans.fit_predict(content)
    score = silhouette_score(content,labels)
    print(f"silhouette_score pour cluster {i} :{score:.3f}")
# Out:
# silhouette_score pour cluster 2 :0.486
# silhouette_score pour cluster 3 :0.380
# silhouette_score pour cluster 4 :0.402
# silhouette_score pour cluster 5 :0.383
# silhouette_score pour cluster 6 :0.339
# silhouette_score pour cluster 7 :0.343
# silhouette_score pour cluster 8 :0.343
# silhouette_score pour cluster 9 :0.320
